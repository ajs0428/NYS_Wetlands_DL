# %%
import rastervision
from rastervision.core.data import RasterioSource

# %%
img = "/ibstorage/anthony/NYS_Wetlands_GHG/Data/TerrainProcessed/HUC_DEMs/cluster_208_huc_041402011002.tif"
rast = RasterioSource(img)

# %%
rast.shape
# Out:
# (12000, 18000, 1)
