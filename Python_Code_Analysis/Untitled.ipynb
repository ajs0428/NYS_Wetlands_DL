# %%
import torch
import torch.nn
import numpy as np

# %%
lst1 = [[123,117,91],[201,195,217],[81, 77, 101]]
type(lst1)
lst1
# Out:
# [[123, 117, 91], [201, 195, 217], [81, 77, 101]]

# %%
arr1 = np.array(lst1)
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
t1 = torch.tensor(lst1)
t2 = torch.tensor(arr1)
t3 = torch.from_numpy(arr1)

print(type(t1))
# Out:
# <class 'torch.Tensor'>

# %%
t1
# Out:
# tensor([[123, 117,  91],
#         [201, 195, 217],
#         [ 81,  77, 101]])

# %%
print(t1.shape)
# Out:
# torch.Size([3, 3])
